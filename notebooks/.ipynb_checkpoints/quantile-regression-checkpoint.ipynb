# %% [markdown]
# # ``Taming Performance Variability''
#
# ### <font color='red'> Notebook for Quantile Regression analysis for both disk and memory data</font>

# %%
import os, sys
import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt
#import seaborn.apionly as sns
import seaborn as sns
import matplotlib.dates as md
from matplotlib import gridspec
import matplotlib.patches as patches
import datetime as dt
from collections import OrderedDict 
from collections import deque
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.regression.quantile_regression import QuantReg
import warnings
from scipy.stats import norm
from IPython.display import IFrame
from IPython.display import Markdown, display
from IPython.display import FileLink, FileLinks

warnings.filterwarnings(action='once')

# With plot_show_and_save() defined below, there is no need for this configuration
# (all plots should use plot_show_and_save())
#%matplotlib inline

# Improve plot quality for retina displays
# %config InlineBackend.figure_format = 'retina'

# Read all inputs from this directory
source_dir = "../data/raw-data/"
# Save all dataframes and plots into this directory 
dest_dir = "output/"

if not os.path.isdir(dest_dir):
    os.mkdir(dest_dir)

# db -- dictinary with keys - table names, values - dataframes with table data
db = {}

for f in os.listdir(source_dir):
    if ".csv" in f:
        db[os.path.splitext(f)[0]] = pd.read_csv(source_dir + f)
    
# Allows setting values in dataframe copies without warnings (default='warn')
pd.options.mode.chained_assignment = None 

# If vebose is set, additional debug info will be printed throughout the notebook
verbose = True
if verbose:
    print "Keys: ", db.keys()
    for k, df in db.iteritems():
        #print "Sample from %s:" % k 
        #print df.head(3), "\n\n" 
        print "Columns in %s:" % k, df.columns 

####  Define default graphics parameters ###

####  Include common helper functions

sys.path.append("bench-lib/")
from common import *
# Out:
# /opt/conda/envs/py27/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Keys:  ['disk_info', 'iperf3_info', 'iperf3_results', 'ping_results', 'env_info', 'membench_info', 'disk_results', 'fio_info', 'stream_info', 'network_info', 'mem_results', 'ping_info']
# Columns in disk_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'disk_name',
#        u'disk_model', u'disk_serial', u'disk_size', u'npartitions',
#        u'disk_type'],
#       dtype='object')
# Columns in iperf3_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'version',
#        u'local_ip', u'local_port', u'remote_ip', u'remote_port',
#        u'remote_nodeid', u'protocol', u'num_streams', u'buffer_size',
#        u'omitted_intervals', u'duration', u'time_units'],
#       dtype='object')
# Columns in iperf3_results: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'reverse',
#        u'retransmits', u'local_cpu_util', u'remote_cpu_util', u'median',
#        u'max', u'min', u'mean', u'stdev', u'sum_sent', u'sum_received',
#        u'units'],
#       dtype='object')
# Columns in ping_results: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'runtime',
#        u'packets_sent', u'packets_received', u'packet_loss', u'max', u'min',
#        u'mean', u'stdev', u'ipg', u'ewma', u'units'],
#       dtype='object')
# Columns in env_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'gcc_ver',
#        u'version_hash', u'total_mem', u'mem_clock_speed', u'arch',
#        u'run_success', u'site', u'nthreads', u'nsockets', u'hw_type'],
#       dtype='object')
# Columns in membench_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'membench_size',
#        u'membench_samples', u'membench_times', u'membench_optimization'],
#       dtype='object')
# Columns in disk_results: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'testname',
#        u'runtime', u'size', u'max', u'min', u'mean', u'stdev', u'units',
#        u'device', u'iodepth'],
#       dtype='object')
# Columns in fio_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'fio_version',
#        u'fio_size', u'fio_iodepth', u'fio_direct', u'fio_numjobs',
#        u'fio_ioengine', u'fio_blocksize', u'fio_timeout'],
#       dtype='object')
# Columns in stream_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'stream_type',
#        u'stream_array_size', u'stream_offset', u'stream_ntimes',
#        u'stream_optimization'],
#       dtype='object')
# Columns in network_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'vlan_name',
#        u'vlan_ip', u'vlan_hwaddr', u'vlan_driver', u'vlan_driver_ver',
#        u'if_name', u'if_hwaddr', u'if_hwinfo', u'if_speed', u'if_duplex',
#        u'if_port_type', u'if_driver', u'if_driver_ver', u'if_bus_location',
#        u'switch_path'],
#       dtype='object')
# Columns in mem_results: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'nthreads_used',
#        u'testname', u'max', u'min', u'mean', u'stdev', u'units', u'socket_num',
#        u'dvfs'],
#       dtype='object')
# Columns in ping_info: Index([u'run_uuid', u'timestamp', u'nodeid', u'nodeuuid', u'ping_version',
#        u'ping_count', u'ping_source_ip', u'ping_dest_ip', u'ping_dest_nodeid',
#        u'ping_size'],
#       dtype='object')

# %%
# Combine disk_results and env_info

disk_all = pd.merge(db['disk_results'], db["env_info"], on=["run_uuid", "nodeid", "nodeuuid", "timestamp"])

# Infer disk_name from device (/dev/sda4 -> /dev/sda)
disk_all["disk_name"] = disk_all["device"].apply(lambda x: x.rstrip(string.digits))

# Add disk info
disk_all = pd.merge(disk_all, db['disk_info'], 
                               on=["run_uuid", "timestamp", "nodeuuid", "disk_name"])  

# df2csv(disk_all, "disk_all.csv", dest_dir)

#disk_full[disk_full["site"] == "clemson"]["nthreads"].value_counts()
disk_all.sample(20).T
# Out:
#                                                    15716   \
# run_uuid             0411a485-fc84-40a9-95b6-3ac3b7be9241
# timestamp                                      1497984378
# nodeid_x                                        clnode157
# nodeuuid             d3b5fcae-fee3-11e5-ba07-000099989701
# testname                                        randwrite
# runtime                                           720.304
# size                                          1.30034e+06
# max                                                  2169
# min                                                     0
# mean                                              1805.78
# stdev                                             115.519
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     619f70a1190c46eff9e5beb7643f4059370f82ed
# total_mem                                          256GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               56
# nsockets                                                2
# hw_type                                             c6320
# disk_name                                        /dev/sda
# nodeid_y                                        clnode157
# disk_model                                   ST91000640NS
# disk_serial                                      9XG9L0VB
# disk_size                                          931.5G
# npartitions                                             4
# disk_type                                             HDD
#
#                                                    111519  \
# run_uuid             50b6ceac-a60f-42d1-8a00-4b2b7d445de8
# timestamp                                      1519996307
# nodeid_x                                           ms0314
# nodeuuid             312e2adb-72db-11e4-85c8-179a28bd1b8c
# testname                                            write
# runtime                                            87.882
# size                                          1.04858e+07
# max                                                122910
# min                                                 88066
# mean                                               119244
# stdev                                             2866.65
# units                                                KB/s
# device                                          /dev/sda2
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                           62GiB
# mem_clock_speed                              Unknown(ARM)
# arch                                              aarch64
# run_success                                             1
# site                                                 utah
# nthreads                                                8
# nsockets                                                1
# hw_type                                              m400
# disk_name                                        /dev/sda
# nodeid_y                                           ms0314
# disk_model                                    XR0120GEBLT
# disk_serial                                  14340D3B760E
# disk_size                                          111.8G
# npartitions                                             3
# disk_type                                             SSD
#
#                                                    78818   \
# run_uuid             bae672e1-c5a9-4918-99b7-7b5a8424dce3
# timestamp                                      1512587228
# nodeid_x                                           ms0222
# nodeuuid             68717e3e-72da-11e4-85c8-179a28bd1b8c
# testname                                        randwrite
# runtime                                           720.287
# size                                           1.4302e+06
# max                                                  2019
# min                                                     0
# mean                                              1985.02
# stdev                                             60.1766
# units                                                KB/s
# device                                          /dev/sda2
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     08a0bec44063cdf3c360cd6e41f0aef75a9c9cc6
# total_mem                                           62GiB
# mem_clock_speed                              Unknown(ARM)
# arch                                              aarch64
# run_success                                             1
# site                                                 utah
# nthreads                                                8
# nsockets                                                1
# hw_type                                              m400
# disk_name                                        /dev/sda
# nodeid_y                                           ms0222
# disk_model                                    XR0120GEBLT
# disk_serial                                  14230C9CDB7B
# disk_size                                          111.8G
# npartitions                                             3
# disk_type                                             SSD
#
#                                                    78702   \
# run_uuid             0fa03535-6c93-445d-922e-d59e0da71385
# timestamp                                      1512523649
# nodeid_x                                    c220g2-011009
# nodeuuid             1c136867-e8ec-11e5-a488-a3bb994732a6
# testname                                            write
# runtime                                           113.571
# size                                          1.04858e+07
# max                                                102320
# min                                                 87224
# mean                                              92333.4
# stdev                                             1991.47
# units                                                KB/s
# device                                           /dev/sdb
# iodepth                                                 1
# gcc_ver                                             5.4.0
# version_hash     08a0bec44063cdf3c360cd6e41f0aef75a9c9cc6
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
# disk_name                                        /dev/sdb
# nodeid_y                                    c220g2-011009
# disk_model                                HUC101212CSS600
# disk_serial                              5000cca072a9a2c8
# disk_size                                            1.1T
# npartitions                                             0
# disk_type                                             HDD
#
#                                                    98784   \
# run_uuid             8472566b-c3ad-4996-88a0-fe057a89e015
# timestamp                                      1516836818
# nodeid_x                                    c220g1-030619
# nodeuuid             ae79c75f-0341-11e6-a488-a3bb994732a6
# testname                                         randread
# runtime                                           720.246
# size                                          2.68884e+06
# max                                                  4071
# min                                                     0
# mean                                              3737.11
# stdev                                             282.622
# units                                                KB/s
# device                                           /dev/sdb
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                          128GiB
# mem_clock_speed                                   1866MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               32
# nsockets                                                2
# hw_type                                            c220g1
# disk_name                                        /dev/sdb
# nodeid_y                                    c220g1-030619
# disk_model                                   ST1200MM0007
# disk_serial                              5000c5007de41d9f
# disk_size                                            1.1T
# npartitions                                             0
# disk_type                                             HDD
#
#                                                    110974  \
# run_uuid             396f3526-90f3-4f8e-a282-c255f66c89e2
# timestamp                                      1519918329
# nodeid_x                                    c220g1-030803
# nodeuuid             fbae02d5-2931-11e6-8934-779211246dcb
# testname                                            write
# runtime                                            54.263
# size                                          1.04858e+07
# max                                                201216
# min                                                128056
# mean                                               193052
# stdev                                             9580.82
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             4.8.4
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                          128GiB
# mem_clock_speed                                   1866MHz
# arch                                               x86_64
# run_success                                             2
# site                                                 wisc
# nthreads                                               32
# nsockets                                                2
# hw_type                                            c220g1
# disk_name                                        /dev/sda
# nodeid_y                                    c220g1-030803
# disk_model                                   ST1200MM0007
# disk_serial                                           NaN
# disk_size                                            1.1T
# npartitions                                             4
# disk_type                                             HDD
#
#                                                    13371   \
# run_uuid             9cf22a88-433b-4289-a270-9d431754deb1
# timestamp                                      1497485069
# nodeid_x                                           ms0222
# nodeuuid             68717e3e-72da-11e4-85c8-179a28bd1b8c
# testname                                            write
# runtime                                           720.003
# size                                           1.4169e+06
# max                                                  2008
# min                                                  1684
# mean                                              1969.64
# stdev                                             10.3109
# units                                                KB/s
# device                                          /dev/sda2
# iodepth                                                 1
# gcc_ver                                             5.4.0
# version_hash     ffa0b0cc7d010c36e7b154dfdb484dc476d9308a
# total_mem                                           62GiB
# mem_clock_speed                              Unknown(ARM)
# arch                                              aarch64
# run_success                                             1
# site                                                 utah
# nthreads                                                8
# nsockets                                                1
# hw_type                                              m400
# disk_name                                        /dev/sda
# nodeid_y                                           ms0222
# disk_model                                    XR0120GEBLT
# disk_serial                                  14230C9CDB7B
# disk_size                                          111.8G
# npartitions                                             3
# disk_type                                             SSD
#
#                                                    113964  \
# run_uuid             9989e542-3a5c-455d-aae0-0a4f0cf9f0fe
# timestamp                                      1520794143
# nodeid_x                                        clnode122
# nodeuuid             cf136bc0-fee2-11e5-ba07-000099989701
# testname                                        randwrite
# runtime                                           720.271
# size                                           1.3618e+06
# max                                                  2433
# min                                                     0
# mean                                              1893.82
# stdev                                             134.878
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                          256GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             2
# site                                              clemson
# nthreads                                               56
# nsockets                                                2
# hw_type                                             c6320
# disk_name                                        /dev/sda
# nodeid_y                                        clnode122
# disk_model                                   ST91000640NS
# disk_serial                                      9XG9LYXV
# disk_size                                          931.5G
# npartitions                                             4
# disk_type                                             HDD
#
#                                                    53800   \
# run_uuid             4727dff2-4357-45b7-aaca-0e39255e1d05
# timestamp                                      1503599205
# nodeid_x                                    c220g2-011327
# nodeuuid             1a2b4d71-e8ec-11e5-a488-a3bb994732a6
# testname                                            write
# runtime                                           130.063
# size                                          1.04858e+07
# max                                                 84408
# min                                                 77632
# mean                                              80625.5
# stdev                                             1192.37
# units                                                KB/s
# device                                           /dev/sdc
# iodepth                                                 1
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
# disk_name                                        /dev/sdc
# nodeid_y                                    c220g2-011327
# disk_model                               INTEL SSDSC2BB48
# disk_serial                            BTWL523502E1480QGN
# disk_size                                          447.1G
# npartitions                                             0
# disk_type                                             SSD
#
#                                                    37666   \
# run_uuid             ded6f834-e787-4e56-8d39-133bded58227
# timestamp                                      1500899254
# nodeid_x                                    c220g2-011324
# nodeuuid             186d0f6b-e8ec-11e5-a488-a3bb994732a6
# testname                                            write
# runtime                                             57.94
# size                                          1.04858e+07
# max                                                195280
# min                                                142592
# mean                                               180718
# stdev                                              8011.1
# units                                                KB/s
# device                                           /dev/sdb
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
# disk_name                                        /dev/sdb
# nodeid_y                                    c220g2-011324
# disk_model                                HUC101212CSS600
# disk_serial                              5000cca0729b797c
# disk_size                                            1.1T
# npartitions                                             0
# disk_type                                             HDD
#
#                                                    118619  \
# run_uuid             64ebb699-502d-47c0-bfd7-007a33325d9b
# timestamp                                      1521613905
# nodeid_x                                    c220g1-031107
# nodeuuid             69b44826-3e70-11e6-b435-eb3e622294a9
# testname                                             read
# runtime                                            98.147
# size                                          1.04858e+07
# max                                                114808
# min                                                 75320
# mean                                               106845
# stdev                                             3686.53
# units                                                KB/s
# device                                           /dev/sdb
# iodepth                                                 1
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                          128GiB
# mem_clock_speed                                   1866MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               32
# nsockets                                                2
# hw_type                                            c220g1
# disk_name                                        /dev/sdb
# nodeid_y                                    c220g1-031107
# disk_model                                   ST1200MM0007
# disk_serial                              5000c5007e0783b7
# disk_size                                            1.1T
# npartitions                                             0
# disk_type                                             HDD
#
#                                                    65969   \
# run_uuid             98cc5287-60fe-466d-9680-bdd754904c13
# timestamp                                      1507766748
# nodeid_x                                           ms0235
# nodeuuid             67346afd-72da-11e4-85c8-179a28bd1b8c
# testname                                         randread
# runtime                                           106.227
# size                                          1.04858e+07
# max                                                185336
# min                                                     7
# mean                                              98584.9
# stdev                                             63187.9
# units                                                KB/s
# device                                          /dev/sda2
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                           62GiB
# mem_clock_speed                              Unknown(ARM)
# arch                                              aarch64
# run_success                                             1
# site                                                 utah
# nthreads                                                8
# nsockets                                                1
# hw_type                                              m400
# disk_name                                        /dev/sda
# nodeid_y                                           ms0235
# disk_model                                    XR0120GEBLT
# disk_serial                                  14230C9CDFC9
# disk_size                                          111.8G
# npartitions                                             3
# disk_type                                             SSD
#
#                                                    9185    \
# run_uuid             8b9f24c1-950a-4cdf-8a3c-92e71f387c12
# timestamp                                      1496903272
# nodeid_x                                    c220g2-011126
# nodeuuid             51d86dee-e8d4-11e5-a488-a3bb994732a6
# testname                                             read
# runtime                                            57.227
# size                                          1.04858e+07
# max                                                203464
# min                                                163752
# mean                                               183152
# stdev                                              8511.3
# units                                                KB/s
# device                                           /dev/sdb
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     ffa0b0cc7d010c36e7b154dfdb484dc476d9308a
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
# disk_name                                        /dev/sdb
# nodeid_y                                    c220g2-011126
# disk_model                                HUC101212CSS600
# disk_serial                              5000cca072aa49b4
# disk_size                                            1.1T
# npartitions                                             0
# disk_type                                             HDD
#
#                                                    6668    \
# run_uuid             d5c38f24-e8c0-4aa0-abdc-04384986cba7
# timestamp                                      1496449659
# nodeid_x                                    c220g2-011301
# nodeuuid             1c88d71c-e8ec-11e5-a488-a3bb994732a6
# testname                                        randwrite
# runtime                                           720.214
# size                                          1.91655e+06
# max                                                  3288
# min                                                     0
# mean                                               2662.2
# stdev                                             137.033
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     ffa0b0cc7d010c36e7b154dfdb484dc476d9308a
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
# disk_name                                        /dev/sda
# nodeid_y                                    c220g2-011301
# disk_model                                HUC101212CSS600
# disk_serial                              5000cca072a924f0
# disk_size                                            1.1T
# npartitions                                             4
# disk_type                                             HDD
#
#                                                    46604   \
# run_uuid             afd1e96a-0b4e-4389-a9d0-52b08805b2c9
# timestamp                                      1502239564
# nodeid_x                                        clnode032
# nodeuuid             d03dfe4d-d7f1-11e4-b34b-000099989701
# testname                                        randwrite
# runtime                                           720.308
# size                                          1.41854e+06
# max                                                  2490
# min                                                     0
# mean                                              1970.67
# stdev                                             131.386
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          256GiB
# mem_clock_speed                                   1333MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               20
# nsockets                                                2
# hw_type                                             c8220
# disk_name                                        /dev/sda
# nodeid_y                                        clnode032
# disk_model                                   ST91000640NS
# disk_serial                                      9XG7MNJC
# disk_size                                          931.5G
# npartitions                                             4
# disk_type                                             HDD
#
#                                                    78902   \
# run_uuid             18aa4911-cdbf-4020-939a-07be483b5580
# timestamp                                      1512588720
# nodeid_x                                    c220g2-011318
# nodeuuid             18fc3782-e8ec-11e5-a488-a3bb994732a6
# testname                                            write
# runtime                                             57.69
# size                                          1.04858e+07
# max                                                194528
# min                                                 56848
# mean                                               181534
# stdev                                             16119.7
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     08a0bec44063cdf3c360cd6e41f0aef75a9c9cc6
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
# disk_name                                        /dev/sda
# nodeid_y                                    c220g2-011318
# disk_model                                HUC101212CSS600
# disk_serial                              5000cca072aa30a4
# disk_size                                            1.1T
# npartitions                                             4
# disk_type                                             HDD
#
#                                                    101681  \
# run_uuid             f8e823a2-6bea-42f4-a0ff-30e9919caf6c
# timestamp                                      1517425898
# nodeid_x                                           ms0211
# nodeuuid             697d6502-72da-11e4-85c8-179a28bd1b8c
# testname                                         randread
# runtime                                           106.325
# size                                          1.04858e+07
# max                                                180248
# min                                                     7
# mean                                              98410.2
# stdev                                             63033.1
# units                                                KB/s
# device                                          /dev/sda2
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                           62GiB
# mem_clock_speed                              Unknown(ARM)
# arch                                              aarch64
# run_success                                             1
# site                                                 utah
# nthreads                                                8
# nsockets                                                1
# hw_type                                              m400
# disk_name                                        /dev/sda
# nodeid_y                                           ms0211
# disk_model                                    XR0120GEBLT
# disk_serial                                  14230C9CDFC5
# disk_size                                          111.8G
# npartitions                                             3
# disk_type                                             SSD
#
#                                                    67023   \
# run_uuid             f2f2ace6-ba8a-4ffe-bc4c-ee1dd83ed396
# timestamp                                      1508329643
# nodeid_x                                    c220g1-031116
# nodeuuid             68c62783-3e70-11e6-b435-eb3e622294a9
# testname                                         randread
# runtime                                           325.022
# size                                          1.04858e+07
# max                                                 33832
# min                                                 31368
# mean                                                32267
# stdev                                             279.285
# units                                                KB/s
# device                                           /dev/sdc
# iodepth                                                 1
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          128GiB
# mem_clock_speed                                   1866MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               32
# nsockets                                                2
# hw_type                                            c220g1
# disk_name                                        /dev/sdc
# nodeid_y                                    c220g1-031116
# disk_model                               INTEL SSDSC2BB48
# disk_serial                            PHWL444204QD480QGN
# disk_size                                          447.1G
# npartitions                                             0
# disk_type                                             SSD
#
#                                                    119630  \
# run_uuid             f3127672-f262-4a79-9cd7-42ca72c81632
# timestamp                                      1521786685
# nodeid_x                                    c220g2-011128
# nodeuuid             50affc6c-e8d4-11e5-a488-a3bb994732a6
# testname                                            write
# runtime                                            57.132
# size                                          1.04858e+07
# max                                                195328
# min                                                128768
# mean                                               183536
# stdev                                               11028
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
# disk_name                                        /dev/sda
# nodeid_y                                    c220g2-011128
# disk_model                                HUC101212CSS600
# disk_serial                              5000cca072aa49cc
# disk_size                                            1.1T
# npartitions                                             4
# disk_type                                             HDD
#
#                                                    24974
# run_uuid             ac8dd7b6-0542-4d9a-916b-5763b7bf761d
# timestamp                                      1499193975
# nodeid_x                                        clnode063
# nodeuuid             d30780a1-d7f1-11e4-b34b-000099989701
# testname                                            write
# runtime                                           101.429
# size                                          1.04858e+07
# max                                                118431
# min                                                 55504
# mean                                               103423
# stdev                                             9107.86
# units                                                KB/s
# device                                          /dev/sda4
# iodepth                                              4096
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          256GiB
# mem_clock_speed                                   1333MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               40
# nsockets                                                2
# hw_type                                             c8220
# disk_name                                        /dev/sda
# nodeid_y                                        clnode063
# disk_model                                   ST91000640NS
# disk_serial                                      9XG7NZGA
# disk_size                                          931.5G
# npartitions                                             4
# disk_type                                             HDD

# %%
# Combine mem_results and env_info

mem_all = pd.merge(db['mem_results'], db["env_info"], on=["run_uuid", "nodeid", "nodeuuid", "timestamp"])
df2csv(mem_all, "mem_all.csv", dest_dir)

mem_all.sample(20).T
# Out:
#                                                    140589  \
# run_uuid             d1c91682-a5f0-4a07-97df-136d0003191b
# timestamp                                      1499669177
# nodeid                                          clnode027
# nodeuuid             cfc58d68-d7f1-11e4-b34b-000099989701
# nthreads_used                                          10
# testname                          write_memory_memset_omp
# max                                               17999.6
# min                                               17900.1
# mean                                              17927.8
# stdev                                                36.6
# units                                                MB/s
# socket_num                                              1
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          256GiB
# mem_clock_speed                                   1333MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               20
# nsockets                                                2
# hw_type                                             c8220
#
#                                                    114648  \
# run_uuid             8747a71f-6e21-40fb-aad1-d5e847537f28
# timestamp                                      1499129196
# nodeid                                          clnode116
# nodeuuid             63911c04-fee2-11e5-ba07-000099989701
# nthreads_used                                          28
# testname                       write_memory_rep_stosq_omp
# max                                               39732.8
# min                                               39477.9
# mean                                              39664.4
# stdev                                                  94
# units                                                MB/s
# socket_num                                              1
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          256GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               56
# nsockets                                                2
# hw_type                                             c6320
#
#                                                    27711   \
# run_uuid             5f20a69c-2c84-4c3a-83a8-0623d2ad258c
# timestamp                                      1496688377
# nodeid                                          clnode099
# nodeuuid             6c29dc56-fee1-11e5-ba07-000099989701
# nthreads_used                                           1
# testname                                  read_memory_avx
# max                                               10843.1
# min                                               10830.3
# mean                                              10838.2
# stdev                                                 4.7
# units                                                MB/s
# socket_num                                              0
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     ffa0b0cc7d010c36e7b154dfdb484dc476d9308a
# total_mem                                          256GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               56
# nsockets                                                2
# hw_type                                             c6320
#
#                                                    295527  \
# run_uuid             8fa5bf45-2894-41c9-a546-3f12dd71d678
# timestamp                                      1504140309
# nodeid                                          clnode100
# nodeuuid             f1fabaaf-fee1-11e5-ba07-000099989701
# nthreads_used                                          28
# testname                                        triad_omp
# max                                               43352.1
# min                                               22818.8
# mean                                              42953.1
# stdev                                             1523.68
# units                                                MB/s
# socket_num                                              0
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          256GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               56
# nsockets                                                2
# hw_type                                             c6320
#
#                                                    320980  \
# run_uuid             f2671a43-f158-4625-ae33-761805068b44
# timestamp                                      1506342528
# nodeid                                      c220g1-031122
# nodeuuid             693d70a3-3e70-11e6-b435-eb3e622294a9
# nthreads_used                                          16
# testname                             write_memory_sse_omp
# max                                               23148.2
# min                                               23038.3
# mean                                              23075.2
# stdev                                                44.1
# units                                                MB/s
# socket_num                                              0
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          128GiB
# mem_clock_speed                                   1866MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               32
# nsockets                                                2
# hw_type                                            c220g1
#
#                                                    666667  \
# run_uuid             b5c1d782-a7cb-471a-98cf-b8614a01be3e
# timestamp                                      1520622727
# nodeid                                             ms1318
# nodeuuid             e2150a3a-8ffe-11e6-8c08-a53a3a50acf8
# nthreads_used                                          16
# testname                                          add_omp
# max                                               23095.6
# min                                               21528.2
# mean                                              22982.7
# stdev                                              114.25
# units                                                MB/s
# socket_num                                              0
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                           64GiB
# mem_clock_speed                                   2400MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 utah
# nthreads                                               16
# nsockets                                                1
# hw_type                                              m510
#
#                                                    166423  \
# run_uuid             8e60f264-84e3-48d1-a8c8-2f5a6bfe37f9
# timestamp                                      1500272856
# nodeid                                      c220g2-011311
# nodeuuid             1942048c-e8ec-11e5-a488-a3bb994732a6
# nthreads_used                                          20
# testname                              read_memory_avx_omp
# max                                               16326.8
# min                                                 16297
# mean                                              16311.5
# stdev                                               10.91
# units                                                MB/s
# socket_num                                              1
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
#
#                                                    704113  \
# run_uuid             bcfd1af1-2b14-406e-8c64-6c58b76fd177
# timestamp                                      1521636545
# nodeid                                          clnode013
# nodeuuid             ce5aa835-d7f1-11e4-b34b-000099989701
# nthreads_used                                          10
# testname                             read_memory_loop_omp
# max                                               39227.7
# min                                               39175.6
# mean                                              39200.1
# stdev                                               16.84
# units                                                MB/s
# socket_num                                              1
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                          256GiB
# mem_clock_speed                                   1333MHz
# arch                                               x86_64
# run_success                                             2
# site                                              clemson
# nthreads                                               20
# nsockets                                                2
# hw_type                                             c8220
#
#                                                    308314  \
# run_uuid             3bf27910-f6dc-4b9a-b9f8-d49bf89e797c
# timestamp                                      1504809963
# nodeid                                          clnode027
# nodeuuid             cfc58d68-d7f1-11e4-b34b-000099989701
# nthreads_used                                           1
# testname                              write_memory_memset
# max                                               7781.61
# min                                               7771.03
# mean                                               7775.5
# stdev                                                3.52
# units                                                MB/s
# socket_num                                              0
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          256GiB
# mem_clock_speed                                   1333MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               20
# nsockets                                                2
# hw_type                                             c8220
#
#                                                    148771  \
# run_uuid             794ae088-5fcd-41c5-97ca-b798cb71f038
# timestamp                                      1499862522
# nodeid                                      c220g2-011308
# nodeuuid             19fd92a8-e8ec-11e5-a488-a3bb994732a6
# nthreads_used                                          20
# testname                                          add_omp
# max                                               12568.2
# min                                               12486.3
# mean                                              12544.2
# stdev                                                 9.4
# units                                                MB/s
# socket_num                                              0
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
#
#                                                    729906  \
# run_uuid             835a11d5-aa7b-47c7-89cc-5f0c561c1949
# timestamp                                      1522325584
# nodeid                                             ms1334
# nodeuuid             e5ce1a60-8ffe-11e6-8c08-a53a3a50acf8
# nthreads_used                                          16
# testname                       write_memory_rep_stosq_omp
# max                                               24965.6
# min                                               24887.2
# mean                                              24944.9
# stdev                                               29.47
# units                                                MB/s
# socket_num                                              0
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                           64GiB
# mem_clock_speed                                   2400MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 utah
# nthreads                                               16
# nsockets                                                1
# hw_type                                              m510
#
#                                                    74489   \
# run_uuid             e9d5b47e-d0c8-43c9-9013-d1ea510454d9
# timestamp                                      1498284479
# nodeid                                             ms0932
# nodeuuid             c576c0a9-8fea-11e6-8c08-a53a3a50acf8
# nthreads_used                                           1
# testname                                 write_memory_avx
# max                                               8249.97
# min                                               8248.14
# mean                                              8249.16
# stdev                                                0.71
# units                                                MB/s
# socket_num                                              0
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                           64GiB
# mem_clock_speed                                   2400MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 utah
# nthreads                                               16
# nsockets                                                1
# hw_type                                              m510
#
#                                                    300940  \
# run_uuid             fd668639-6eac-4f50-870a-bad4ff57f2fc
# timestamp                                      1504421110
# nodeid                                          clnode035
# nodeuuid             d0855f0c-d7f1-11e4-b34b-000099989701
# nthreads_used                                           1
# testname                         read_memory_prefetch_avx
# max                                               12123.5
# min                                               12113.6
# mean                                              12120.9
# stdev                                                3.66
# units                                                MB/s
# socket_num                                              1
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          256GiB
# mem_clock_speed                                   1333MHz
# arch                                               x86_64
# run_success                                             1
# site                                              clemson
# nthreads                                               20
# nsockets                                                2
# hw_type                                             c8220
#
#                                                    335663  \
# run_uuid             208f82f2-0095-4f8f-b0a7-3fc936c68bb2
# timestamp                                      1508112335
# nodeid                                             ms0727
# nodeuuid             b89b8f74-74c8-11e4-85c8-179a28bd1b8c
# nthreads_used                                           8
# testname                                         copy_omp
# max                                               19947.1
# min                                               18383.5
# mean                                                19398
# stdev                                              226.46
# units                                                MB/s
# socket_num                                              0
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                           62GiB
# mem_clock_speed                              Unknown(ARM)
# arch                                              aarch64
# run_success                                             1
# site                                                 utah
# nthreads                                                8
# nsockets                                                1
# hw_type                                              m400
#
#                                                    312192  \
# run_uuid             f8e782e3-411e-4240-91f7-a9da1ac08db5
# timestamp                                      1505543268
# nodeid                                      c220g2-011315
# nodeuuid             192a3769-e8ec-11e5-a488-a3bb994732a6
# nthreads_used                                           1
# testname                                             copy
# max                                               9595.85
# min                                                9025.9
# mean                                              9567.72
# stdev                                               81.43
# units                                                MB/s
# socket_num                                              1
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
#
#                                                    311881  \
# run_uuid             0f109d5e-3966-48da-b9a2-776bc760acb7
# timestamp                                      1505500070
# nodeid                                      c220g2-011315
# nodeuuid             192a3769-e8ec-11e5-a488-a3bb994732a6
# nthreads_used                                          20
# testname                     read_memory_prefetch_avx_omp
# max                                               16314.2
# min                                               16301.4
# mean                                              16308.5
# stdev                                                4.56
# units                                                MB/s
# socket_num                                              1
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2
#
#                                                    446657  \
# run_uuid             2b61908e-e611-4339-84fc-d3ee27e9cceb
# timestamp                                      1513041998
# nodeid                                      c220g1-031122
# nodeuuid             693d70a3-3e70-11e6-b435-eb3e622294a9
# nthreads_used                                           1
# testname                                  read_memory_sse
# max                                               10184.6
# min                                                 10161
# mean                                                10177
# stdev                                                8.42
# units                                                MB/s
# socket_num                                              1
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     08a0bec44063cdf3c360cd6e41f0aef75a9c9cc6
# total_mem                                          128GiB
# mem_clock_speed                                   1866MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               32
# nsockets                                                2
# hw_type                                            c220g1
#
#                                                    598112  \
# run_uuid             8b5b0ab5-1423-4219-8721-a7995521a50e
# timestamp                                      1517620289
# nodeid                                             ms0212
# nodeuuid             6964e048-72da-11e4-85c8-179a28bd1b8c
# nthreads_used                                           1
# testname                                             copy
# max                                               9662.35
# min                                               9527.06
# mean                                              9607.81
# stdev                                                21.5
# units                                                MB/s
# socket_num                                              0
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                           62GiB
# mem_clock_speed                              Unknown(ARM)
# arch                                              aarch64
# run_success                                             1
# site                                                 utah
# nthreads                                                8
# nsockets                                                1
# hw_type                                              m400
#
#                                                    391638  \
# run_uuid             37f4cc71-f482-4005-a9f4-3c4db7f570eb
# timestamp                                      1511119577
# nodeid                                      c220g1-030617
# nodeuuid             af49f97e-0341-11e6-a488-a3bb994732a6
# nthreads_used                                          16
# testname                                        scale_omp
# max                                               33145.8
# min                                               32435.2
# mean                                              33026.3
# stdev                                                  57
# units                                                MB/s
# socket_num                                              1
# dvfs                                                   no
# gcc_ver                                             5.4.0
# version_hash     6e2eedd0f3c165252682c45e34764016278edd06
# total_mem                                          128GiB
# mem_clock_speed                                   1866MHz
# arch                                               x86_64
# run_success                                             1
# site                                                 wisc
# nthreads                                               32
# nsockets                                                2
# hw_type                                            c220g1
#
#                                                    707067
# run_uuid             edda4a58-2fc1-45df-8648-22f85e6d8d05
# timestamp                                      1521700380
# nodeid                                      c220g2-011020
# nodeuuid             1a88cfea-e8ec-11e5-a488-a3bb994732a6
# nthreads_used                                           1
# testname                                 write_memory_avx
# max                                               7358.74
# min                                               7342.47
# mean                                              7348.63
# stdev                                                5.92
# units                                                MB/s
# socket_num                                              0
# dvfs                                                  yes
# gcc_ver                                             5.4.0
# version_hash     9e67da94c8dc1846d9131ca4dbd0d6c5fb41307d
# total_mem                                          160GiB
# mem_clock_speed                                   2133MHz
# arch                                               x86_64
# run_success                                             2
# site                                                 wisc
# nthreads                                               40
# nsockets                                                2
# hw_type                                            c220g2

# %%
# This Quantile Regression analysis is inspired by: https://dl.acm.org/citation.cfm?id=2451140

def qr_fit_model(qr, factor, q):
    res = qr.fit(q=q)
    res_df = pd.DataFrame([{"q": q}]) 
    for p in res.params.index.values:
        res_df[p] = res.params[p]
        res_df[str(p) + "_lb"] = res.conf_int().loc[p, 0]
        res_df[str(p) + "_ub"] = res.conf_int().loc[p, 1]
    return res_df

def qr_factor_analysis(name, df, metric, factor, quantiles=np.arange(.05, .96, .05), verbose=True):

    if verbose:
        print "Number of samples: ", len(df)
        
    qr = smf.quantreg('%s ~ %s' % (metric, factor), df)
    qr_models = pd.DataFrame()
    for q in quantiles:
        qr_models = qr_models.append(qr_fit_model(qr, factor, q), ignore_index=True)
    
    if verbose:    
        print qr_models
    
    vars = list(set([c.replace("_lb", "").replace("_ub", "") for c in qr_models.columns if c != "q"]))
    
    # Rearrange such that "Intercept" goes first
    vars = ["Intercept"] + [v for v in vars if v != "Intercept"]
    
    color_map = get_cmap_from_list(vars)
    
    # Find proper label for Intercept
    intercept_label = "Intercept"
    if factor in df.columns.tolist():
        used_types = set([v.split(".")[1].rstrip("]") for v in vars if v != "Intercept"])
        all_types = set(df[factor].unique())
        intercept_candidates = list(all_types - used_types)
        if len(intercept_candidates) > 1:
            print "Error: multiple candidate labels are found for Intercept"
        intercept_label = "Base Case: %s" % intercept_candidates[0] 
    
    fig, ax = plt.subplots(figsize=(8.5, 4))
    
    for v in vars:
        ax.plot(qr_models.q, qr_models[v], color=color_map[v], label=v if v != "Intercept" else intercept_label,
               lw=3.0 if v == "Intercept" else 1.0)
        ax.plot(qr_models.q, qr_models[str(v)+"_lb"], linestyle='dotted', color=color_map[v], label='_nolegend_')
        ax.plot(qr_models.q, qr_models[str(v)+"_ub"], linestyle='dotted', color=color_map[v], label='_nolegend_')
        #ax.set_title(name + ", " + v)   
    
    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    plot_show_and_save(fig, "qr-%s-%s.pdf" % (name, factor), dest_dir)

# %%
m_st = subset_df(mem_all, {"testname": "add", "dvfs": "yes", "socket_num": 0})
m_mt = subset_df(mem_all, {"testname": "add_omp", "dvfs": "yes", "socket_num": 0})    
    
qr_factor_analysis("ST", m_st, "mean", "hw_type", verbose=False)
qr_factor_analysis("MT", m_mt, "mean", "hw_type", verbose=False)
# Out:
# /opt/conda/envs/py27/lib/python2.7/site-packages/patsy/util.py:652: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   return safe_is_pandas_categorical_dtype(data.dtype)
# /notebooks/output/qr-ST-hw_type.pdf
# /notebooks/output/qr-MT-hw_type.pdf

# %%
# Compare two specific nodes using quantile regression

# This system-to-system comparison is insipred by: 
# https://htor.inf.ethz.ch/publications/img/hoefler-scientific-benchmarking.pdf

quantiles = np.arange(.05, .96, .05)

def qr_fit_model(qr, q):
    res = qr.fit(q=q)
    return [q, res.params['Intercept'], res.params['zero']] + res.conf_int().loc['Intercept'].tolist()

def qr_compare(pair, metric):
    # Color-coding based on nodeid
    color_labels = [el["nodeid"] for el in pair]
    rgb_values = sns.color_palette("bright", len(pair))
    color_map = dict(zip(color_labels, rgb_values))
    
    df = pd.DataFrame()
    for p in pair:
        subset = db['disk_results']
        print "Starting # of samples: ", len(subset)
        label = ""
        for k,v in p.iteritems():
            subset = subset[subset[k] == v]
            label += str(v) + ", "
            print "Selecting based on %s=%s. # of samples: %d" % (k, v, len(subset))
        
        # Handle vectors of different lengths
        if len(df) == 0: 
            # df[p["nodeid"]] = subset[metric].tolist()
            df[0] = subset[metric].tolist()
        else:
            if len(df) > len(subset):
                df[1] = subset[metric].tolist() + [np.nan] * (len(df) - len(subset)) 
            # Need to handle the else case
    # print df.dropna() 
    df = df.dropna() 
    
    # Convert to MB/s
    df[0] = df[0] / 1024.0
    df[1] = df[1] / 1024.0
    
    df["diff"] = df[1] - df[0]
    #print df
    
    df["zero"] = 0.0

    qr = smf.quantreg('diff ~ zero', df)
    qr_models = [qr_fit_model(qr, x) for x in quantiles]
    qr_models = pd.DataFrame(qr_models, columns=['q', 'intercept', 'slope', 'intercept_lb', 'intercept_ub'])

    ols = smf.ols('diff ~ zero', df).fit()
    ols_ci = ols.conf_int().loc['Intercept'].tolist()
    ols = dict(intercept = ols.params['Intercept'],
               slope = ols.params['zero'],
               intercept_lb = ols_ci[0],
               intercept_ub = ols_ci[1])
    
    fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(15,4))
    
    sns.distplot(df[1], color=color_map[pair[1]["nodeid"]], ax = ax1);
    ax1.set_title("Node A")
    ax1.set_xlabel("%s with iodepth=%d, MB/s" % (pair[1]["testname"], pair[1]["iodepth"]))
    sns.distplot(df[0], color=color_map[pair[0]["nodeid"]], ax = ax2);
    ax2.set_title("Node B")
    ax2.set_xlabel("%s with iodepth=%d, MB/s" % (pair[0]["testname"], pair[0]["iodepth"]))   
    
    n = qr_models.shape[0]
    ax3.plot(qr_models.q, qr_models.intercept, color='black', label='Quantile Reg.')
    ax3.plot(qr_models.q, qr_models.intercept_ub, linestyle='dotted', color='black')
    ax3.plot(qr_models.q, qr_models.intercept_lb, linestyle='dotted', color='black')
    ax3.plot(qr_models.q, [ols['intercept']] * n, color='red', label='OLS')
    ax3.plot(qr_models.q, [ols['intercept_lb']] * n, linestyle='dotted', color='red')
    ax3.plot(qr_models.q, [ols['intercept_ub']] * n, linestyle='dotted', color='red')
    ax3.set_title("Difference between A and B")
    plt.xlabel('Quantiles')
    plt.legend()
    
    fig.tight_layout()
    
    plot_show_and_save(fig, "", "", show_only=True)
    
pair = [OrderedDict([("nodeid","c220g2-011308"), ("device","/dev/sda4"), ("testname","read"), ("iodepth",4096)]), 
        OrderedDict([("nodeid","c220g2-010823"), ("device","/dev/sda4"), ("testname","read"), ("iodepth",4096)])]
qr_compare(pair, "mean")

pair = [OrderedDict([("nodeid","c220g2-011308"), ("device","/dev/sda4"), ("testname","read"), ("iodepth",4096)]), 
        OrderedDict([("nodeid","c220g2-011323"), ("device","/dev/sda4"), ("testname","read"), ("iodepth",4096)])]
qr_compare(pair, "mean")

pair = [OrderedDict([("nodeid","c220g2-011308"), ("device","/dev/sdc"), ("testname","randread"), ("iodepth",1)]), 
        OrderedDict([("nodeid","c220g2-010823"), ("device","/dev/sdc"), ("testname","randread"), ("iodepth",1)])]
qr_compare(pair, "mean")
# Out:
# Starting # of samples:  141408
# Selecting based on nodeid=c220g2-011308. # of samples: 1920
# Selecting based on device=/dev/sda4. # of samples: 640
# Selecting based on testname=read. # of samples: 160
# Selecting based on iodepth=4096. # of samples: 80
# Starting # of samples:  141408
# Selecting based on nodeid=c220g2-010823. # of samples: 1200
# Selecting based on device=/dev/sda4. # of samples: 400
# Selecting based on testname=read. # of samples: 100
# Selecting based on iodepth=4096. # of samples: 50
# /opt/conda/envs/py27/lib/python2.7/site-packages/statsmodels/regression/quantile_regression.py:237: RuntimeWarning: invalid value encountered in less_equal
#   kernels['epa'] = lambda u: 3. / 4 * (1-u**2) * np.where(np.abs(u) <= 1, 1, 0)
# /opt/conda/envs/py27/lib/python2.7/site-packages/statsmodels/nonparametric/kde.py:475: DeprecationWarning: object of type <type 'numpy.float64'> cannot be safely interpreted as an integer.
#   grid,delta = np.linspace(a,b,gridsize,retstep=True)
# Starting # of samples:  141408
# Selecting based on nodeid=c220g2-011308. # of samples: 1920
# Selecting based on device=/dev/sda4. # of samples: 640
# Selecting based on testname=read. # of samples: 160
# Selecting based on iodepth=4096. # of samples: 80
# Starting # of samples:  141408
# Selecting based on nodeid=c220g2-011323. # of samples: 1800
# Selecting based on device=/dev/sda4. # of samples: 600
# Selecting based on testname=read. # of samples: 150
# Selecting based on iodepth=4096. # of samples: 75
# Starting # of samples:  141408
# Selecting based on nodeid=c220g2-011308. # of samples: 1920
# Selecting based on device=/dev/sdc. # of samples: 640
# Selecting based on testname=randread. # of samples: 160
# Selecting based on iodepth=1. # of samples: 80
# Starting # of samples:  141408
# Selecting based on nodeid=c220g2-010823. # of samples: 1200
# Selecting based on device=/dev/sdc. # of samples: 400
# Selecting based on testname=randread. # of samples: 100
# Selecting based on iodepth=1. # of samples: 50
